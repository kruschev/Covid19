# %%
import pandas as pd
import json

# %%
flight = pd.read_csv('flight_status.csv')

# %%
pd.set_option('display.max_rows', 200)

flight[flight.to=='SGN']
# Out:
#       from   to  active
# 167    LHR  SGN       0
# 6551   FUK  SGN       0
# 6610   NGO  SGN       0
# 6675   KIX  SGN       1
# 6795   HND  SGN       1
# 6895   NRT  SGN       1
# 7030   PEK  SGN       0
# 7126   CTU  SGN       0
# 7268   CAN  SGN       0
# 7435   KMG  SGN       0
# 7501   NNG  SGN       1
# 7631   PVG  SGN       0
# 7725   SZX  SGN       1
# 7825   WUH  SGN       0
# 7866   XMN  SGN       0
# 7884   XIY  SGN       0
# 8031   HKG  SGN       1
# 8163   KHH  SGN       0
# 8191   RMQ  SGN       0
# 8285   TPE  SGN       1
# 8376   PUS  SGN       0
# 8521   ICN  SGN       1
# 8798   DEL  SGN       1
# 8877   CCU  SGN       0
# 8942   BOM  SGN       0
# 9192   BWN  SGN       1
# 9223   PNH  SGN       1
# 9241   REP  SGN       1
# 9267   KOS  SGN       1
# 9319   CGK  SGN       0
# 9391   DPS  SGN       0
# 9416   PKZ  SGN       0
# 9435   JHB  SGN       1
# 9550   KUL  SGN       1
# 9598   PEN  SGN       1
# 9630   RGN  SGN       0
# 9744   MNL  SGN       1
# 9858   SIN  SGN       1
# 9998   BKK  SGN       1
# 10051  DMK  SGN       0
# 10134  CNX  SGN       0
# 10199  HKT  SGN       0
# 10218  UTH  SGN       0
# 11248  DOH  SGN       1
# 11812  DXB  SGN       0
# 13482  CDG  SGN       1
# 18195  FRA  SGN       0
# 19716  ZRH  SGN       0
# 25640  SVO  SGN       1
# 27350  IST  SGN       0
# 28404  HEL  SGN       0
# 30197  MEL  SGN       1
# 30268  SYD  SGN       1

# %%
airport = pd.read_json('airport.json')

# %%
airport
# Out:
#                         country    location  \
# 0                       Algeria       Adrar
# 1                       Algeria     Algiers
# 2                       Algeria      Annaba
# 3                       Algeria       Batna
# 4                       Algeria      Bejaia
# ...                         ...         ...
# 1300                     Tuvalu    Funafuti
# 1301                    Vanuatu  Luganville
# 1302                    Vanuatu   Port Vila
# 1303  Wallis and Futuna Islands      Futuna
# 1304  Wallis and Futuna Islands      Wallis
#
#                                             name code
# 0     Touat-Cheikh Sidi Mohamed Belkebir Airport  AZR
# 1                     Houari Boumedienne Airport  ALG
# 2                            Rabah Bitat Airport  AAE
# 3                                  Batna Airport  BLJ
# 4                                Soummam Airport  BJA
# ...                                          ...  ...
# 1300              Funafuti International Airport  FUN
# 1301           Santo-Pekoa International Airport  SON
# 1302            Bauerfield International Airport  VLI
# 1303                         Pointe Vele Airport  FUT
# 1304                              Hihifo Airport  WLS
#
# [1305 rows x 4 columns]

# %%
airport[airport.code=='CDG']
# Out:
#      country location                       name code
# 837  Belgium    Paris  Charles de Gaulle Airport  CDG

# %%
df = pd.read_csv('flight_status_merged.csv')

# %%
df
# Out:
#       from   to  active               country_from location_from  \
# 0      LHR  ALG       1             United Kingdom        London
# 1      LHR  PER       1             United Kingdom        London
# 2      LHR  VIE       1             United Kingdom        London
# 3      LHR  GYD       1             United Kingdom        London
# 4      LHR  BAH       1             United Kingdom        London
# ...    ...  ...     ...                        ...           ...
# 30756  VLI  SUV       0                    Vanuatu     Port Vila
# 30757  VLI  MEL       0                    Vanuatu     Port Vila
# 30758  WLS  NAN       1  Wallis and Futuna Islands        Wallis
# 30759  WLS  NOU       1  Wallis and Futuna Islands        Wallis
# 30760  WLS  FUT       1  Wallis and Futuna Islands        Wallis
#
#                               name_from                 country_to  \
# 0                      Heathrow Airport                    Algeria
# 1                      Heathrow Airport                  Australia
# 2                      Heathrow Airport                    Austria
# 3                      Heathrow Airport                    Albania
# 4                      Heathrow Airport                    Bahrain
# ...                                 ...                        ...
# 30756  Bauerfield International Airport                       Fiji
# 30757  Bauerfield International Airport                  Australia
# 30758                    Hihifo Airport                       Fiji
# 30759                    Hihifo Airport              New Caledonia
# 30760                    Hihifo Airport  Wallis and Futuna Islands
#
#       location_to                              name_to
# 0         Algiers           Houari Boumedienne Airport
# 1           Perth                        Perth Airport
# 2          Vienna         Vienna International Airport
# 3            Baku  Heydar Aliyev International Airport
# 4          Manama        Bahrain International Airport
# ...           ...                                  ...
# 30756        Suva        Nausori International Airport
# 30757   Melbourne                    Melbourne Airport
# 30758        Nadi           Nadi International Airport
# 30759      Nouméa    La Tontouta International Airport
# 30760      Futuna                  Pointe Vele Airport
#
# [30761 rows x 9 columns]

# %%
air
