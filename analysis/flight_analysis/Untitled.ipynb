# %%
import pandas as pd

# %%
airport = pd.read_csv('airport.csv')

# %%
airport
# Out:
#                 country    location  \
# 0               Algeria       Adrar
# 1               Algeria     Algiers
# 2               Algeria      Annaba
# 3               Algeria       Batna
# 4               Algeria      Bejaia
# ...                 ...         ...
# 1300             Tuvalu    Funafuti
# 1301            Vanuatu  Luganville
# 1302            Vanuatu   Port Vila
# 1303  Wallis and Futuna      Futuna
# 1304  Wallis and Futuna      Wallis
#
#                                             name code
# 0     Touat-Cheikh Sidi Mohamed Belkebir Airport  AZR
# 1                     Houari Boumedienne Airport  ALG
# 2                            Rabah Bitat Airport  AAE
# 3                                  Batna Airport  BLJ
# 4                                Soummam Airport  BJA
# ...                                          ...  ...
# 1300              Funafuti International Airport  FUN
# 1301           Santo-Pekoa International Airport  SON
# ...

# %%
airport[airport.country== 'Finland']
# Out:
#       country      location                      name code
# 1186  Finland         Åland         Mariehamn Airport  MHQ
# 1187  Finland      Helsinki   Helsinki-Vantaa Airport  HEL
# 1188  Finland       Kittilä           Kittilä Airport  KTT
# 1189  Finland        Kuopio            Kuopio Airport  KUO
# 1190  Finland       Kuusamo           Kuusamo Airport  KAO
# 1191  Finland  Lappeenranta      Lappeenranta Airport  LPP
# 1192  Finland          Oulu              Oulu Airport  OUL
# 1193  Finland     Rovaniemi         Rovaniemi Airport  RVN
# 1194  Finland       Tampere  Tampere-Pirkkala Airport  TMP
# 1195  Finland         Turku             Turku Airport  TKU
# 1196  Finland         Vaasa             Vaasa Airport  VAA
